# %% [markdown]
# <a href="https://colab.research.google.com/github/00deepureddy/STAT/blob/main/DL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 7. Use the concept of Data Augmentation to increase the data size
# from a single image.

# %%
import cv2
import numpy as np
import albumentations as A
import os

def augment_image(image_path, output_folder, num_augmented=10):

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    transform = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.Rotate(limit=30, p=0.5),
        A.RandomBrightnessContrast(p=0.5),
        A.GaussianBlur(blur_limit=(3, 7), p=0.3),
        A.GaussNoise(var_limit=(10.0, 50.0), p=0.3),
    ])

    for i in range(num_augmented):
        augmented = transform(image=image)
        augmented_image = augmented["image"]

        save_path = os.path.join(output_folder, f"augmented_{i}.jpg")
        cv2.imwrite(save_path, cv2.cvtColor(augmented_image, cv2.COLOR_RGB2BGR))

    print(f"{num_augmented} augmented images saved in {output_folder}")

image_path = "/d5.jpg"
output_folder = "augmented_images"
augment_image(image_path, output_folder, num_augmented=10)
# Out:
# /tmp/ipython-input-3046959140.py:20: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0), p=0.3),
# 10 augmented images saved in augmented_images

# %% [markdown]
# 9. Design and implement a CNN model to classify CIFAR10 im
# age dataset. Use Data Augmentation while designing the CNN
# model. Record accuracy corresponding to the number of epochs.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

datasets = {
    "MNIST": tf.keras.datasets.mnist.load_data(),
    "Fashion-MNIST": tf.keras.datasets.fashion_mnist.load_data()
}

for dataset_name, (data_train, data_test) in datasets.items():

    (x_train, y_train), (x_test, y_test) = data_train, data_test

    x_train, x_test = x_train / 255.0, x_test / 255.0

    x_train = x_train.reshape(-1, 28, 28, 1)
    x_test = x_test.reshape(-1, 28, 28, 1)

    y_train = tf.keras.utils.to_categorical(y_train, 10)
    y_test = tf.keras.utils.to_categorical(y_test, 10)

    model = models.Sequential([
        layers.Conv2D(6, (5, 5), activation='tanh', padding='same', input_shape=(28, 28, 1)),
        layers.AveragePooling2D((2, 2)),
        layers.Conv2D(16, (5, 5), activation='tanh'),
        layers.AveragePooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(120, activation='tanh'),
        layers.Dense(84, activation='tanh'),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        epochs=15,
                        batch_size=128,
                        validation_data=(x_test, y_test),
                        verbose=1)

    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
    print(f"\n{dataset_name} Test Accuracy: {test_acc:.4f}\n")

    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'LeNet-5 Accuracy on {dataset_name}')
    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8234 - loss: 0.6138 - val_accuracy: 0.9556 - val_loss: 0.1473
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9582 - loss: 0.1399 - val_accuracy: 0.9710 - val_loss: 0.0969
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9737 - loss: 0.0878 - val_accuracy: 0.9776 - val_loss: 0.0749
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9803 - loss: 0.0652 - val_accuracy: 0.9762 - val_loss: 0.0694
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9839 - loss: 0.0522 - val_accuracy: 0.9817 - val_loss: 0.0510
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9875 - loss: 0.0403 - val_accuracy: 0.9841 - val_loss: 0.0530
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9895 - loss: 0.0348 - val_accuracy: 0.9844 - val_loss: 0.0501
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9917 - loss: 0.0272 - val_accuracy: 0.9845 - val_loss: 0.0482
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9915 - loss: 0.0255 - val_accuracy: 0.9846 - val_loss: 0.0489
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9937 - loss: 0.0201 - val_accuracy: 0.9863 - val_loss: 0.0447
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9953 - loss: 0.0156 - val_accuracy: 0.9873 - val_loss: 0.0428
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9955 - loss: 0.0145 - val_accuracy: 0.9839 - val_loss: 0.0494
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9952 - loss: 0.0140 - val_accuracy: 0.9863 - val_loss: 0.0453
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9971 - loss: 0.0101 - val_accuracy: 0.9860 - val_loss: 0.0427
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9975 - loss: 0.0092 - val_accuracy: 0.9845 - val_loss: 0.0567
# 313/313 - 1s - 5ms/step - accuracy: 0.9845 - loss: 0.0567
#
# MNIST Test Accuracy: 0.9845
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7024 - loss: 0.8412 - val_accuracy: 0.8284 - val_loss: 0.4708
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8505 - loss: 0.4189 - val_accuracy: 0.8517 - val_loss: 0.4065
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8680 - loss: 0.3647 - val_accuracy: 0.8592 - val_loss: 0.3833
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8770 - loss: 0.3353 - val_accuracy: 0.8676 - val_loss: 0.3622
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8859 - loss: 0.3101 - val_accuracy: 0.8763 - val_loss: 0.3421
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8903 - loss: 0.2998 - val_accuracy: 0.8776 - val_loss: 0.3343
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8952 - loss: 0.2839 - val_accuracy: 0.8827 - val_loss: 0.3312
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9003 - loss: 0.2673 - val_accuracy: 0.8841 - val_loss: 0.3203
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9060 - loss: 0.2548 - val_accuracy: 0.8823 - val_loss: 0.3270
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9087 - loss: 0.2461 - val_accuracy: 0.8892 - val_loss: 0.3058
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9147 - loss: 0.2308 - val_accuracy: 0.8857 - val_loss: 0.3089
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9164 - loss: 0.2264 - val_accuracy: 0.8914 - val_loss: 0.3094
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9213 - loss: 0.2156 - val_accuracy: 0.8929 - val_loss: 0.2973
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9236 - loss: 0.2071 - val_accuracy: 0.8922 - val_loss: 0.3042
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9265 - loss: 0.1999 - val_accuracy: 0.8938 - val_loss: 0.3002
# 313/313 - 1s - 4ms/step - accuracy: 0.8938 - loss: 0.3002
#
# Fashion-MNIST Test Accuracy: 0.8938

# %% [markdown]
# 10. Implement the standard VGG-16 & VGG-19 CNN architecture
# model stoclassify multi-category image datasets and check the accuracy.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)

datagen.fit(x_train)

def build_vgg_model(vgg_type="VGG16"):

    base_model = VGG16(weights=None, include_top=False, input_shape=(32, 32, 3)) if vgg_type == "VGG16" \
        else VGG19(weights=None, include_top=False, input_shape=(32, 32, 3))

    model = models.Sequential([
        base_model,
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

for vgg_type in ["VGG16", "VGG19"]:

    print(f"\nTraining {vgg_type} Model...\n")

    model = build_vgg_model(vgg_type)

    history = model.fit(
        datagen.flow(x_train, y_train, batch_size=64),
        validation_data=(x_test, y_test),
        epochs=3,
        verbose=1
    )

    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
    print(f"\n{vgg_type} Test Accuracy: {test_acc:.4f}\n")

    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f'Accuracy of {vgg_type} on CIFAR-10')
    plt.show()
# Out:
# Training VGG16 Model...
#
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 71ms/step - accuracy: 0.0986 - loss: 2.3032 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.0950 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.0988 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# 313/313 - 2s - 7ms/step - accuracy: 0.1000 - loss: 2.3026
#
# VGG16 Test Accuracy: 0.1000
# Training VGG19 Model...
#
# Epoch 1/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 94ms/step - accuracy: 0.1024 - loss: 2.3031 - val_accuracy: 0.1000 - val_loss: 2.3027
# Epoch 2/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.0988 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 3/3
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 86ms/step - accuracy: 0.1005 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# 313/313 - 3s - 9ms/step - accuracy: 0.1000 - loss: 2.3026
#
# VGG19 Test Accuracy: 0.1000

# %% [markdown]
# 11. Implement RNN for sentiment analysis on movie reviews.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing
import matplotlib.pyplot as plt

vocab_size = 10000
max_length = 200

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=max_length)
x_test = preprocessing.sequence.pad_sequences(x_test, maxlen=max_length)

model = models.Sequential([
    layers.Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    layers.SimpleRNN(64, activation='tanh', return_sequences=True),
    layers.SimpleRNN(32, activation='tanh'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=3,          # changed here
                    batch_size=64,
                    validation_data=(x_test, y_test),
                    verbose=1)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc:.4f}\n")

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('RNN Accuracy on IMDb Sentiment Analysis')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/3
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.5935 - loss: 0.6540 - val_accuracy: 0.6550 - val_loss: 0.6077
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.7929 - loss: 0.4420 - val_accuracy: 0.6963 - val_loss: 0.5775
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8766 - loss: 0.3038 - val_accuracy: 0.8010 - val_loss: 0.4924
# 782/782 - 7s - 9ms/step - accuracy: 0.8010 - loss: 0.4924
#
# Test Accuracy: 0.8010

# %% [markdown]
# 12. Implement Bidirectional LSTM for sentiment analysis on movie
# reviews

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, preprocessing
import matplotlib.pyplot as plt

vocab_size = 10000
max_length = 200

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=max_length)
x_test = preprocessing.sequence.pad_sequences(x_test, maxlen=max_length)

model = models.Sequential([
    layers.Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
    layers.Bidirectional(layers.LSTM(32)),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    epochs=3,          # changed to 3
                    batch_size=64,
                    validation_data=(x_test, y_test),
                    verbose=1)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc:.4f}\n")

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Bidirectional LSTM Accuracy on IMDb Sentiment Analysis')
plt.show()
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.7302 - loss: 0.5085 - val_accuracy: 0.8504 - val_loss: 0.3575
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.9143 - loss: 0.2215 - val_accuracy: 0.8570 - val_loss: 0.3320
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.9450 - loss: 0.1582 - val_accuracy: 0.8660 - val_loss: 0.3273
# 782/782 - 9s - 12ms/step - accuracy: 0.8660 - loss: 0.3273
#
# Test Accuracy: 0.8660
